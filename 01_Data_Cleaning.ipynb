# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
DATA_PATH = Path("data/raw")

# %%
orders = pd.read_csv(DATA_PATH / "Ir4_wc_order_stats.csv")

# %%
print(os.getcwd())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(os.getcwd())
#
# NameError: name 'os' is not defined

# %%
list(DATA_PATH.iterdir())
# Out:
# [PosixPath('data/raw/Ir4_posts.csv'),
#  PosixPath('data/raw/Ir4_postmeta.csv'),
#  PosixPath('data/raw/Ir4_woocommerce_order_items.csv'),
#  PosixPath('data/raw/Ir4_wc_product_meta_lookup.csv'),
#  PosixPath('data/raw/Ir4_woocommerce_order_itemmeta.csv'),
#  PosixPath('data/raw/Ir4_wc_customer_lookup.csv'),
#  PosixPath('data/raw/Ir4_wc_order_stats.csv'),
#  PosixPath('data/raw/Ir4_wc_order_coupon_lookup.csv'),
#  PosixPath('data/raw/Ir4_wdr_order_item_discounts.csv')]

# %%
import os

# %%
print(os.getcwd())
# Out:
# /Users/raj/Downloads/AI-Ecommerce-Analytics

# %%
print(DATA_PATH.exists())
# Out:
# True

# %%
orders = pd.read_csv(DATA_PATH / "Ir4_wc_order_stats.csv")

# %%
orders.head(150)
# Out:
#     order_id;"parent_id";"date_created";"date_created_gmt";"num_items_sold";"total_sales";"tax_total";"shipping_total";"net_total";"returning_customer";"status";"customer_id";"date_paid";"date_completed"
# 0    216;"0";"2022-03-13 17:12:55";"2022-03-13 17:1...
# 1    217;"0";"2022-03-13 17:16:02";"2022-03-13 17:1...
# 2    2199;"0";"2022-03-14 09:44:17";"2022-03-14 09:...
# 3    2642;"0";"2022-03-14 13:45:18";"2022-03-14 13:...
# 4    2643;"0";"2022-03-14 13:48:14";"2022-03-14 13:...
# ..                                                 ...
# 145  3376;"0";"2022-03-16 14:02:01";"2022-03-16 14:...
# 146  3377;"0";"2022-03-16 14:02:18";"2022-03-16 14:...
# 147  3379;"0";"2022-03-16 14:23:07";"2022-03-16 14:...
# 148  3380;"0";"2022-03-16 14:28:13";"2022-03-16 14:...
# 149  3381;"0";"2022-03-16 14:33:46";"2022-03-16 14:...
#
# [150 rows x 1 columns]
